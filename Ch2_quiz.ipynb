# %% [markdown]
# #### Q1 국어 80, 영어 75, 수학 55점일 때 평균 점수를 구해 보자.

# %%
(80+75+55)/3
# Out:
# 70.0

# %% [markdown]
# #### Q2 자연수 13이 홀수인지 짝수인지 판별할 수 있는 방법에 대해 말해 보자.

# %%
a = 13
if a % 2 == 0:
    print("짝수")
else:
    print("홀수")
# Out:
# 홀수

# %% [markdown]
# #### Q3 홍길동 씨의 주민등록번호는 881120-1068234이다. 홍길동 씨의 주민등록번호를 연월일(YYYYMMDD) 부분과 그 뒤의 숫자 부분으로 나누어 출력해 보자.

# %%
a = "881120-1068234"
a[0:6]
# Out:
# '881120'

# %%
a[7:]
# Out:
# '1068234'

# %% [markdown]
# #### Q4 주민등록번호 뒷자리의 맨 첫 번째 숫자는 성별을 나타낸다. 주민등록번호에서 성별을 나타내는 숫자를 출력해 보자.
#
# >>> pin = "881120-1068234"

# %%
pin = "881120-1068234"
pin[7]
# Out:
# '1'

# %% [markdown]
# #### Q5 문자열 a:b:c:d를 replace 함수를 사용하여 a#b#c#d로 바꿔서 출력해 보자.

# %%
a = "a:b:c:d"
a.replace(":", "#")
# Out:
# 'a#b#c#d'

# %% [markdown]
# #### Q6 [1,3,5,4,2] 리스트를 [5,4,3,2,1]로 만들어 보자.

# %%
a = [1,3,5,4,2]
a.sort()
a
# Out:
# [1, 2, 3, 4, 5]

# %%
a.reverse()

# %%
a
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# #### Q7 ['Life', 'is', 'too', 'short'] 리스트를 Life is too short 문자열로 만들어 출력해 보자.

# %%
a = ['Life', 'is', 'too', 'short']
' '.join(a)
# Out:
# 'Life is too short'

# %% [markdown]
# #### Q8 (1,2,3) 튜플에 값 4를 추가하여 (1,2,3,4)를 만들어 출력해 보자.

# %%
(1,2,3)+(4,)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# #### Q9 다음과 같은 딕셔너리 a가 있다.
# 다음 중 오류가 발생하는 경우를 고르고, 그 이유를 설명해 보자.

# %%
a = dict()
a
# Out:
# {}

# %%
a['name']='python'
a
# Out:
# {'name': 'python'}

# %%
a = dict()
a
# Out:
# {}

# %%
a[('a',)]='python'
a
# Out:
# {('a',): 'python'}

# %%
a = dict()
a
# Out:
# {}

# %%
a[[1]]='python'
a  # 리스트는 딕셔너리의 key 값으로 사용할 수 없다.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-ec0d22283cdf> in <module>()
# ----> 1 a[[1]]='python'
#       2 a
#
# TypeError: unhashable type: 'list'

# %%
a[250]='python'
a
# Out:
# {250: 'python'}

# %% [markdown]
# #### Q10 딕셔너리 a에서 'B'에 해당하는 값을 추출해 보자.

# %%
a = {'A':90, 'B':80, 'C':70}

# %%
a['B']
# Out:
# 80

# %% [markdown]
# #### Q11 a 리스트에서 중복 숫자를 제거해 보자.

# %%
a = [1,1,1,2,2,3,3,3,4,4,5]

# %%
set(a)  # 집합은 원소의 중복을 허용하지 않음
# Out:
# {1, 2, 3, 4, 5}

# %%
list(set(a))
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# #### Q12 파이썬은 다음처럼 동일한 값에 여러 개의 변수를 선언할 수 있다. 다음과 같이 a,b 변수를 선언한 후 a의 두 번째 요솟값을 변경하면 b값은 어떻게 될까? 그리고 이런 결과가 오는 이유에 대해 설명해 보자.

# %%
a = b = [1,2,3]  # 리스트 복사
a[1] = 4
print(b)
# Out:
# [1, 4, 3]

# %% [markdown]
# ##### 12-1) b[1]을 바꾸지 않는 방법

# %%
a = b = [1,2,3]
b = a[:]  # b는 a와 다른 객체라고 선언
a[1] = 4
a
# Out:
# [1, 4, 3]

# %%
b
# Out:
# [1, 2, 3]
